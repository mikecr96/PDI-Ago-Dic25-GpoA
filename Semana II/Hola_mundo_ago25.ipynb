# %% [markdown]
# # Clase introducción a los notebooks

# %% [markdown]
# ## Subtítulo

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ---

# %%
letra = "m"
numero = 10
flotante = 3.14151926
lista = [12, 12, 12, 21, 21, 21]

# %%
print(letra)
# Out:
# m

# %%
print("Saludos grupo de PDI")
# Out:
# Saludos grupo de PDI

# %%
print("Hola mundo!")
# Out:
# Hola mundo!

# %% [markdown]
# ## Conversión de tipo de dato

# %%
letra
# Out:
# 'm'

# %%
type(letra)
# Out:
# str

# %%
type(123)
# Out:
# int

# %%
# Conversión de string a entero (cast)
numeroEnString = "100"
numeroEnInt = int(numeroEnString)

# %%
type(numeroEnString)
# Out:
# str

# %%
type(numeroEnInt)
# Out:
# int

# %%
# int("hola mundo")

# %%
int(3.1416)
# Out:
# 3

# %%
float(3)
# Out:
# 3.0

# %%
# Tupla a lista
tupla = (1, 2, 3)
type(tupla)
# Out:
# tuple

# %%
tupleToList = list(tupla)
type(tupleToList)
# Out:
# list

# %%
tuple([1, 2, 3])
# Out:
# (1, 2, 3)

# %%
type(tuple([1, 2, 3]))
# Out:
# tuple
